# %%
# import libraries

import numpy as np
import pandas as pd
import math
import itertools

import gc
import os
import json
from collections import Counter, defaultdict
from tqdm.notebook import tqdm
from datetime import datetime, timedelta

import matplotlib.pyplot as plt
from matplotlib.cm import ScalarMappable
import plotly.graph_objs as go
import kaleido

import plotly.express as px
import re
year_pattern = r'([1-2][0-9]{3})'

# %%
from basic_utils import *

# Major constants

MAX_EXTRACTION_LENGTH = 5000  # How many publications to load to save time 
MAX_PUBLICATIONS = 100 # max publications allowed to consider an author (otherwise it's likely a non-unique name)
MIN_PUBLICATIONS = 0

YEARS_BINSIZE = 1.0  # how large bins to group together on derivative calculation
    # DONT change this unless you check where it propagates

# %% [markdown]
# ### Extract data by publication

# %%
# Create a pandas dataframe with each publication information 

# Create an empty list to accumulate rows
rows = []

length = 0
metadata = get_metadata()
for paper in metadata:
    if length > MAX_EXTRACTION_LENGTH:
        break
    paper_data = json.loads(paper)
    
    # Extract and process the data
    categories = list(set([check_in_major_categories(cat) for cat in paper_data['categories'].split() 
                  if check_in_major_categories(cat) is not None])) # removes duplicates
    if len(categories) == 0:
        continue  # skip this one, it's a weird paper with no normal tags 
    paper_id = paper_data['id']
    pub_date = extract_decimal_year_of_pub(paper_data['versions'])
    authors_parsed = paper_data['authors_parsed']
    
    # Create a dictionary with the extracted data
    row = {'id': paper_id, 'categories': categories, 'pub_date': pub_date, 'authors_parsed': authors_parsed}

    # Append the row to the rows list
    rows.append(row)
    
    if length % 100_000 == 0:
        print(length, 'done')
    length += 1

# Create a DataFrame using the accumulated rows
columns = ['id', 'categories', 'pub_date', 'authors_parsed']
df = pd.DataFrame(rows, columns=columns)

print(len(df))
# Out:
# 0 done
# 5001

# %% [markdown]
# ### Get unique categories and mapping

# %%
# Get a list of all unique categories
unique_categories = sorted(set(cat for categories in df['categories'] for cat in categories))

def index_to_category(ind):
    return unique_categories[ind]

def category_to_index(cat):
    return unique_categories.index(cat)

print(unique_categories)
# Out:
# ['astro-ph', 'astro-ph.EP', 'astro-ph.HE', 'cond-mat.dis-nn', 'cond-mat.mes-hall', 'cond-mat.mtrl-sci', 'cond-mat.other', 'cond-mat.quant-gas', 'cond-mat.soft', 'cond-mat.stat-mech', 'cond-mat.str-el', 'cond-mat.supr-con', 'cs.AI', 'cs.AR', 'cs.CC', 'cs.CE', 'cs.CG', 'cs.CL', 'cs.CR', 'cs.CV', 'cs.CY', 'cs.DB', 'cs.DC', 'cs.DL', 'cs.DM', 'cs.DS', 'cs.ET', 'cs.GL', 'cs.GT', 'cs.HC', 'cs.IR', 'cs.IT', 'cs.LG', 'cs.LO', 'cs.MA', 'cs.MM', 'cs.MS', 'cs.NA', 'cs.NE', 'cs.NI', 'cs.OH', 'cs.PF', 'cs.PL', 'cs.RO', 'cs.SC', 'cs.SE', 'econ.EM', 'gr-qc', 'hep-ex', 'hep-lat', 'hep-ph', 'hep-th', 'math-ph', 'math.AC', 'math.AG', 'math.AP', 'math.AT', 'math.CA', 'math.CO', 'math.CT', 'math.CV', 'math.DG', 'math.DS', 'math.FA', 'math.GM', 'math.GN', 'math.GR', 'math.GT', 'math.HO', 'math.IT', 'math.KT', 'math.LO', 'math.MG', 'math.MP', 'math.NA', 'math.NT', 'math.OA', 'math.OC', 'math.PR', 'math.QA', 'math.RA', 'math.RT', 'math.SG', 'math.SP', 'math.ST', 'nlin.AO', 'nlin.CD', 'nlin.CG', 'nlin.PS', '
# ...

# %% [markdown]
# ### Extract data by author

# %%
# Create a dictionary with the contributions of each unique author name. 

# Initialize an empty dictionary to store the authors and their papers
author_papers = {}

# Iterate through the rows of the DataFrame
for index, row in df.iterrows():
    
    paper_id = row['id']
    categories = row['categories']
    pub_date = row['pub_date']
    authors_parsed = row['authors_parsed']

    # Iterate through the authors of each paper
    for author in authors_parsed:
        author_key = "".join(author)  # Create a unique author key

        # If the author is not in the dictionary, add them with their first paper
        if author_key not in author_papers:
            author_papers[author_key] = []

        # Add the paper information to the author's list of papers
        author_papers[author_key].append([paper_id, pub_date, categories])

print(len(author_papers))
# Out:
# 13493

# %% [markdown]
# ### Extract author status data by date

# %%
"""
# Initialize the author_status_metadata 
# Contains a list of categories currently being published by each author during each timebin
# as well as the previous author's time bin

# An author is only considered active in years where they publish something. 
    
"""

author_status_metadata = defaultdict(list)

for author_key, papers in author_papers.items():
    if not (MIN_PUBLICATIONS <= len(papers) <= MAX_PUBLICATIONS):
        continue  # only use authors with a few publications, or not too many (otherwise likely a non-unique name)

    bin_size = YEARS_BINSIZE
    binned_papers = defaultdict(set)

    # Bin the papers by date
    for p in papers:
        _, date, categories_as_words = p
        binned_date = bin_date(date, bin_size)
        categories_as_indices = set([category_to_index(item) for item in categories_as_words])
        binned_papers[binned_date].update(categories_as_indices)

    # Find the min and max binned dates
    min_binned_date = bin_date(min(date for date in binned_papers.keys()), bin_size)
    max_binned_date = bin_date(max(date for date in binned_papers.keys()), bin_size)

    # Iterate over the binned dates in the known range
    current_date = min_binned_date
    prev_year_categories = set(binned_papers[min_binned_date])
    while current_date <= max_binned_date + 0.5 * bin_size:  # add 0.5 to not miss last bin
        if binned_papers[current_date]:
            current_year_categories = set(binned_papers[current_date])
            author_status_metadata[current_date].append([list(current_year_categories), list(prev_year_categories)])
        
        prev_year_categories = current_year_categories
        current_date = bin_date(current_date + 1.01*bin_size, bin_size)  # add 1.01 to make sure to reach next bin
        
sorted_dates = list(sorted(author_status_metadata.keys()))
print(len(sorted_dates))
# Out:
# 1

# %%
# Now for each bin, we can take the list of papers, and measure things. 

def count_authors_by_category(author_status_data, unique_categories):
    category_count = np.zeros(len(unique_categories))

    for author in author_status_data:
        current_categories = author[0]
        weight = 1 / len(current_categories)
        for category in current_categories:
            category_count[category] += weight

    return category_count

def count_transitions(author_status_data, unique_categories):    
    """
    Gets the transition matrix. first index is source, second index is target
    The entry is the number of transitions from one field to another. 
    """
    
    transition_count = np.zeros((len(unique_categories), len(unique_categories)))
    
    for author in author_status_data:
        current_categories = author[0]
        previous_categories = author[1]

        transition_vector = np.zeros(len(unique_categories))

        for cat in current_categories:
            transition_vector[cat] += 1 / len(current_categories)        
        for cat in previous_categories:
            transition_vector[cat] -= 1 / len(previous_categories)

        neg_source_mask = transition_vector[previous_categories] < 0
        pos_target_mask = transition_vector[current_categories] > 0

        for source_index, source_neg in zip(previous_categories, neg_source_mask):
            if not source_neg:
                continue

            ratio = (-transition_vector[source_index]) / np.sum(-transition_vector[transition_vector < 0])
            for target_index, target_pos in zip(current_categories, pos_target_mask):
                if target_pos:
                    transition_count[source_index, target_index] += ratio * transition_vector[target_index]

    return transition_count

author_counts = {date: count_authors_by_category(author_status_metadata[date], unique_categories) for date in sorted_dates}
author_transitions = {date: count_transitions(author_status_metadata[date], unique_categories) for date in sorted_dates}
print('done')
# Out:
# done

# %% [markdown]
# ## Save the data to json for reloading

# %%
# To save to JSON we need to convert numpy arrays to lists and back and forth

# Save the dictionary to a JSON file
with open('author_counts.json', 'w') as f:
    convert_dict_of_arrays_to_dict_of_lists(author_counts)
    json.dump(author_counts, f)
with open('author_transitions.json', 'w') as f:
    convert_dict_of_arrays_to_dict_of_lists(author_transitions)
    json.dump(author_transitions, f)

# %%
# Load the dictionary from the JSON file, as a dictionary of numpy arrays
with open('author_counts.json', 'r') as f:
    author_counts = json.load(f)
    convert_dict_of_arrays_to_dict_of_lists(author_counts)
with open('author_transitions.json', 'r') as f:
    author_transitions = json.load(f)
    convert_dict_of_arrays_to_dict_of_lists(author_transitions)

# %% [markdown]
# # old

# %%
# Get the rates of transitions, rather than the total movement

MIN_COUNTS_TO_REPORT_RATE = 20

# Get net transition to/from each pair, and get rate 
# these are matrices 
author_net_transitions = {date: author_transitions[date] - author_transitions[date].T for date in sorted_dates}
author_net_rate = {date: author_net_transitions[date]/np.maximum(author_counts[date].reshape(-1,1),
                                                                 MIN_COUNTS_TO_REPORT_RATE)
                   for date in sorted_dates}

# Get sums along target objects, to just have the net for each source 
author_net_transitions_vec = {date: np.sum(author_net_transitions[date], axis=1) for date in sorted_dates}
author_net_rate_vec = {date: np.sum(author_net_rate[date], axis=1) for date in sorted_dates}

# %% [markdown]
# ### Functions to collapse categories

# %%
def collapse_categories_function_major(cat):
    """
    This is the major categories collapse.
    
    Returns AI fields if category is in there
    Otherwise returns some major category 
    """
    
    # Basic dictionary to condense categories down to prefixes. 
    AI_fields = {
    'cs.AI',
    'cs.NA',
    'cs.LG',
    'cs.CV',
    'cs.SY',
    'cs.CL',
    'cs.RO',
    'stat.ML',
    'eess.AS',
    'eess.IV',
    'eess.SP'
    }

    # dictionary to condense prefixes further 
    prefix_condensation_dict = defaultdict(lambda: 'other')
    prefix_condensation_dict.update({
    'astro-ph' : 'astrophysics',
    'cond-mat' : 'cond. mat. phys.',
    'cs' : 'comp. sci. (non AI)',
    'gr' : 'physics',
    'hep' : 'nuc. high. en. phys.',
    'math' : 'math',
    'nucl' : 'nuc. high. en. phys.',
    'physics' : 'physics',
    'q-bio' : 'physics',
    'quant-ph' : 'physics',
    'stat' : 'stats (non AI)',
    'econ' : 'other',
    'nlin' : 'other',
    'q-fin' : 'other',
    })

    if cat in AI_fields:
        return 'AI fields'
    else:
        for pattern in prefix_condensation_dict.keys():
            if cat.lower().startswith(pattern.lower()):
                return prefix_condensation_dict[pattern]
    return 'other'


def collapse_categories_function_specific(cat, explore_specific_field_prefix):
    """
    This one loads a specific prefix but keeps all subfields, and puts the rest in 'other'
    
    Useful for seeing relative strength of subfields
    """
    
    # explore_specific_field_prefix = 'cs'
    
    if cat.lower().startswith(explore_specific_field_prefix.lower()):
        return cat
    else:
        return 'other'
    
def collapse_categories_function_all(cat):
    """
    This one keeps all categories. No change 
    """
    return cat


collapse_kind = 'major' # 'specific'
explore_specific_field_prefix = 'cs'

if collapse_kind == 'major':
    collapse_categories_function = collapse_categories_function_major
elif collapse_kind == 'specific':
    collapse_categories_function = lambda cat: collapse_categories_function_specific(cat, explore_specific_field_prefix)
else:
    collapse_categories_function = collapse_categories_function_all

collapse_categories_function('nucl-ex')
# Out:
# 'nuc. high. en. phys.'

# %%
def create_collapse_index_mapping(collapse_dict):
    unique_categories = list(sorted(set(collapse_dict.keys())))
    collapsed_unique_categories = list(sorted(set(collapse_dict.values())))
    index_mapping = {}

    for ind, cat in enumerate(unique_categories):
        collapsed_cat = collapse_dict[cat]
        collapsed_ind = collapsed_unique_categories.index(collapsed_cat)
        index_mapping[ind] = collapsed_ind

    return index_mapping, collapsed_unique_categories

def collapse_transition_matrix(transition_count, index_mapping):
    """
    Careful here. Don't count transitions that are within a collapsed class. 
    """
    
    n_collapsed = len(set(index_mapping.values()))
    collapsed_transition_count = np.zeros((n_collapsed, n_collapsed))

    for source_ind, collapsed_source_ind in index_mapping.items():
        for target_ind, collapsed_target_ind in index_mapping.items():
            
            # Only add to matrix if we are transitioning in or out of classes. 
            if collapsed_target_ind != collapsed_source_ind: 
                collapsed_transition_count[collapsed_source_ind, collapsed_target_ind] += transition_count[source_ind, target_ind]

    return collapsed_transition_count

def collapse_vector(vector, index_mapping):
    
    n_collapsed = len(set(index_mapping.values()))
    collapsed_vector = np.zeros(n_collapsed)

    for source_ind, collapsed_source_ind in index_mapping.items():
        collapsed_vector[collapsed_source_ind] += vector[source_ind]

    return collapsed_vector

# %%
# Get collapsed datasets for easy plotting 

collapse_dict = {cat : collapse_categories_function(cat) for cat in unique_categories}
collapse_index_mapping, unique_categories_collapsed = create_collapse_index_mapping(collapse_dict)

# vectors
author_counts_collapsed = {date: collapse_vector(author_counts[date], collapse_index_mapping) 
                               for date in sorted_dates}
author_net_transitions_vec_collapsed = {date: collapse_vector(author_net_transitions_vec[date], collapse_index_mapping) 
                               for date in sorted_dates}
author_net_rate_vec_collapsed = {date: (author_net_transitions_vec_collapsed[date]
                                        / np.maximum(author_counts_collapsed[date], MIN_COUNTS_TO_REPORT_RATE))
                               for date in sorted_dates}

# 2D matrices 
author_transitions_collapsed = {date: collapse_transition_matrix(author_transitions[date], collapse_index_mapping) 
                               for date in sorted_dates}
author_net_transitions_collapsed = {date: author_transitions_collapsed[date] - author_transitions_collapsed[date].T
                               for date in sorted_dates}
author_rate_collapsed = {date: (author_transitions_collapsed[date]
                                    / np.maximum(author_counts_collapsed[date].reshape(-1,1), MIN_COUNTS_TO_REPORT_RATE))    
                               for date in sorted_dates}
author_net_rate_collapsed = {date: (author_net_transitions_collapsed[date]
                                    / np.maximum(author_counts_collapsed[date].reshape(-1,1), MIN_COUNTS_TO_REPORT_RATE))    
                               for date in sorted_dates}

print(author_transitions_collapsed[sorted_dates[-1]].shape)
# Out:
# (9, 9)

# %% [markdown]
# ## Display results

# %% [markdown]
# Get cumulative net transitions into or out of field divided by size.

# %%
# Some plotting choices
START_YEAR_PLOT = 2000
END_YEAR_PLOT = 2023
IGNORE_CATEGORIES = ['other']
FIG_XSIZE = 600
FIG_YSIZE = 280

def plot_vec(vec_data, 
             category_names=unique_categories_collapsed, 
             title="ArXiv author number, by field", 
             yaxis_title="Authors publishing per year",
             plt_range=None
            ):
    fig = go.Figure()

    # Plot the data and add labels to the lines
    for which_cat, category_name in enumerate(category_names):
        if category_name in IGNORE_CATEGORIES:
            continue
            
        plt_vals = [vec_data[date][which_cat] 
                    for date in sorted_dates if 
                    (date < END_YEAR_PLOT) and (date > START_YEAR_PLOT)]
        #fig.add_trace(go.Scatter(x=date, y=deriv_x, mode='lines+markers', marker=dict(size=3), name=category_name))
        fig.add_trace(go.Scatter(
            x=[date for date in sorted_dates if 
                    (date < END_YEAR_PLOT) and (date > START_YEAR_PLOT)],
            y=plt_vals,
            mode='lines+markers',
            marker=dict(size=3),
            name=category_name,
            hovertemplate='%{y:.2f}',
            # line=dict(color='gray', width=1),
            hoverinfo='name+y',
        ))    

    # Customize the layout
    fig.update_layout(
        title=title,
        xaxis_title="Years",
        yaxis_title=yaxis_title,
        hovermode="closest",
        width=FIG_XSIZE,
        height=FIG_YSIZE,
        margin=dict(l=10, r=50, t=50, b=50)
    )
    
    if plt_range is not None:
        fig.update_layout(yaxis_range=[-plt_range, plt_range])

    return fig
    
def plot_matrix(matrix_data, source_index,
             category_names=unique_categories_collapsed, 
             title="Author counts", 
             yaxis_title="Total per year",
                plt_range = None
            ):
    
    vec_data = {date: matrix_data[date][source_index] for date in sorted_dates}
    
    fig = plot_vec(vec_data, 
             category_names=unique_categories_collapsed, 
             title=title, 
             yaxis_title=yaxis_title,
            plt_range = plt_range)
    
    return fig

# %%
# Some plotting choices
START_YEAR_PLOT = 2000
END_YEAR_PLOT = 2023
IGNORE_CATEGORIES = ['other (econ./fin. and nlin)']
FIG_XSIZE = 600
FIG_YSIZE = 350

def plot_vec(ax, vec_data,
             category_names=unique_categories_collapsed,
             title="ArXiv author number, by field",
             yaxis_title="Authors publishing per year",
             plt_range=None
            ):
    
    cmap = plt.get_cmap('tab20')
    sm = ScalarMappable(cmap=cmap, norm=plt.Normalize(0, len(category_names)))
    color_cycle = itertools.cycle([sm.to_rgba(v) for v in range(len(category_names))])

    # Plot the data and add labels to the lines
    for which_cat, category_name in enumerate(category_names):
        if category_name in IGNORE_CATEGORIES:
            continue

        plt_vals = [vec_data[date][which_cat]
                    for date in sorted_dates if
                    (date < END_YEAR_PLOT) and (date > START_YEAR_PLOT)]

        ax.plot([date for date in sorted_dates if
                 (date < END_YEAR_PLOT) and (date > START_YEAR_PLOT)],
                plt_vals,
                marker='o', markersize=1.5,
                color=next(color_cycle),
                label=category_name
               )

    # Customize the layout
    ax.set_title(title)
    ax.set_xlabel("Years")
    ax.set_ylabel(yaxis_title)
    ax.legend(loc='upper left')

    if plt_range is not None:
        ax.set_ylim(-plt_range, plt_range)

def plot_matrix(ax, matrix_data, source_index,
                category_names=unique_categories_collapsed,
                title="Author counts",
                yaxis_title="Total per year",
                plt_range=None
               ):

    vec_data = {date: matrix_data[date][source_index] for date in sorted_dates}

    plot_vec(ax, vec_data,
                   category_names=unique_categories_collapsed,
                   title=title,
                   yaxis_title=yaxis_title,
                   plt_range=plt_range
                  )
    
def plot_matrix_cumulative(ax, matrix_data, source_index,
                category_names=unique_categories_collapsed,
                title="Author counts",
                yaxis_title="Total per year",
                plt_range=None
               ):

    vec_data = {date_now: np.sum(np.array([matrix_data[date_past][source_index] 
                                           for date_past in sorted_dates
                                           if date_past <= date_now
                                          ]), axis=0) 
                for date_now in sorted_dates}

    plot_vec(ax, vec_data,
                   category_names=unique_categories_collapsed,
                   title=title,
                   yaxis_title=yaxis_title,
                   plt_range=plt_range
                  )

# %%
fig, ax = plt.subplots(figsize=(FIG_XSIZE / 80, FIG_YSIZE / 80))
plot_vec(ax, author_counts_collapsed)
plt.show()
fig.savefig('Author_number_by_field.png', dpi=300)

fig, ax = plt.subplots(figsize=(FIG_XSIZE / 80, FIG_YSIZE / 80))
plot_vec(ax, author_net_rate_vec_collapsed, 
         title="(net transitions out of field) / (size of field)",
         yaxis_title="Rate per year")
ax.plot([START_YEAR_PLOT, END_YEAR_PLOT], [0,0], color= 'black')
plt.show()
fig.savefig('Net_transition_rate_by_field.png', dpi=300)

# %%
# plot_matrix(author_net_rate_collapsed, 4, title="TBD",
#          yaxis_title="TBD")
plt_range = 0.05
fig_scaling = 0.6
for cat in unique_categories_collapsed:
    fig, ax = plt.subplots(figsize=(fig_scaling*FIG_XSIZE / 80, fig_scaling*FIG_YSIZE / 80))
    plot_matrix(ax, author_net_rate_collapsed, unique_categories_collapsed.index(cat),
                title="Net transitions from " + cat + " to [other field]\n / (size of " + cat + ")",
                yaxis_title="Probability per year",
               plt_range=plt_range)
    ax.plot([START_YEAR_PLOT, END_YEAR_PLOT], [0,0], color= 'black')
    ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    plt.show()
    fig.savefig('Transition_rate_from_' + cat + '_by_field.png', dpi=300)

# %%
# plot_matrix(author_net_rate_collapsed, 4, title="TBD",
#          yaxis_title="TBD")
plt_range = 0.05
fig_scaling = 0.6
for cat in unique_categories_collapsed:
    fig, ax = plt.subplots(figsize=(fig_scaling*FIG_XSIZE / 80, fig_scaling*FIG_YSIZE / 80))
    plot_matrix(ax, author_net_transitions_collapsed, unique_categories_collapsed.index(cat),
                title="Net transitions from " + cat + " to [other field]",
                yaxis_title="Authors per year")
    ax.plot([START_YEAR_PLOT, END_YEAR_PLOT], [0,0], color= 'black')
    ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    plt.show()
    fig.savefig('Transitions_from_' + cat + '_by_field.png', dpi=300)

# %%
# plot_matrix(author_net_rate_collapsed, 4, title="TBD",
#          yaxis_title="TBD")
plt_range = 0.05
fig_scaling = 0.6
for cat in unique_categories_collapsed:
    fig, ax = plt.subplots(figsize=(fig_scaling*FIG_XSIZE / 80, fig_scaling*FIG_YSIZE / 80))
    plot_matrix_cumulative(ax, author_net_transitions_collapsed, unique_categories_collapsed.index(cat),
                title="Cumulative net transitions from " + cat + " to [other field]",
                yaxis_title="Authors total")
    ax.plot([START_YEAR_PLOT, END_YEAR_PLOT], [0,0], color= 'black')
    ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    plt.show()
    fig.savefig('Cumulative_transitions_from_' + cat + '_by_field.png', dpi=300)

# %%
# plot_matrix(author_net_rate_collapsed, 4, title="TBD",
#          yaxis_title="TBD")
plt_range = 0.05
fig_scaling = 0.6
for cat in unique_categories_collapsed:
    fig, ax = plt.subplots(figsize=(fig_scaling*FIG_XSIZE / 80, fig_scaling*FIG_YSIZE / 80))
    plot_matrix_cumulative(ax, author_net_rate_collapsed, unique_categories_collapsed.index(cat),
                title="Cumulative net transition rate from " + cat + " to [other field]",
                yaxis_title="Author switch probability total")
    ax.plot([START_YEAR_PLOT, END_YEAR_PLOT], [0,0], color= 'black')
    ax.legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
    plt.show()
    fig.savefig('Cumulative_transition_rate_from_' + cat + '_by_field.png', dpi=300)

# %% [markdown]
# ## Heatmap matrix

# %%
def plot_heatmap(matrix, node_labels, plt_range, date_name):
    fig, ax = plt.subplots(figsize = (3.3, 3.3))
    im = ax.imshow(matrix, cmap='bwr', vmin=-plt_range, vmax=plt_range)

    ax.set_xticks(np.arange(matrix.shape[1]))
    ax.set_yticks(np.arange(matrix.shape[0]))

    ax.set_xticklabels(node_labels)
    ax.set_yticklabels(node_labels)

    # Rotate x-axis tick labels
    for tick in ax.get_xticklabels():
        tick.set_rotation(85)
        
    ax.set_xlabel("To node")
    ax.set_ylabel("From this node\n(per size of this node)")
    ax.set_title("Directed Transition\nMatrix in " + date_name)

    fig.colorbar(im, ax=ax)

    plt.show()

for date_ind in [-2 -3*_i for _i in range(0)]:
    plt_range = 0.05
    date_name = str(sorted_dates[date_ind])
    matrix = author_net_rate_collapsed[sorted_dates[date_ind]]
    print(np.sum(np.abs(matrix + matrix.T)))

    plot_heatmap(matrix, unique_categories_collapsed, plt_range, date_name)

# %%
def plot_heatmaps_row(matrix_list, node_labels, plt_range, date_names):
    fig, axes = plt.subplots(1, len(matrix_list), figsize=(2.3 * len(matrix_list), 2.3), sharex=True, sharey=True)

    for i, (matrix, date_name, ax) in enumerate(zip(matrix_list, date_names, axes)):
        im = ax.imshow(matrix, cmap='bwr', vmin=-plt_range, vmax=plt_range)

        ax.set_xticks(np.arange(matrix.shape[1]))
        ax.set_yticks(np.arange(matrix.shape[0]))

        if i == 0:
            ax.set_xticklabels(node_labels)
            ax.set_yticklabels(node_labels)
            ax.set_ylabel("From this node\n(per size of this node)")
        else:
            ax.set_xticklabels(node_labels)
            ax.set_yticklabels(node_labels)

        # Rotate x-axis tick labels
        for tick in ax.get_xticklabels():
            tick.set_rotation(85)
        
        ax.set_xlabel("To node")
        ax.set_title(date_name)

    cbar = fig.colorbar(im, ax=axes, shrink=0.7)
    
    # Get the position of the colorbar
    pos = cbar.ax.get_position()

    # Set a new position for the colorbar
    pos.x0 = pos.x0 - 0.025
    pos.x1 = pos.x1 - 0.025
    cbar.ax.set_position(pos)
    cbar.set_label('Rate per yr', labelpad=10)
    
    plt.show()
    return fig

date_inds = list(reversed([-2 - 1 * _i for _i in range(8)]))
matrix_list = [author_net_rate_collapsed[sorted_dates[date_ind]] for date_ind in date_inds]
date_names = [str(math.floor(sorted_dates[date_ind]))+'-'+str(math.ceil(sorted_dates[date_ind])) for date_ind in date_inds]
plt_range = 0.05

fig = plot_heatmaps_row(matrix_list, unique_categories_collapsed, plt_range, date_names)
fig.savefig('Transition_heatmaps.png', dpi=300)
